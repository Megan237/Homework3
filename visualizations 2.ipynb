# %%
import pandas as panda
import matplotlib

data = panda.read_csv("Employee.csv")
data.Age.plot.box()
# Out:
# <Axes: >

# %%
data_avg = data.Education.groupby(data.Education).count()
data_avg.plot.pie(y="Education")
# Out:
# <Axes: ylabel='Education'>

# %%
data.plot.scatter(x=0, y = 2, color = 'Blue',label='' )
# Out:
# <Axes: xlabel='Education', ylabel='City'>
