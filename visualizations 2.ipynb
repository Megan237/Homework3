# %%
import pandas as panda
import matplotlib.pyplot as plt
import seaborn as sns

data = panda.read_csv("Employee.csv")
data.Age.plot.box()
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
data_avg = data.Education.groupby(data.Education).count()
data_avg.plot.pie(title="Education")
# Out:
# <Axes: title={'center': 'Education'}, ylabel='Education'>

# %%
edu_leave = data.groupby(['Education', 'LeaveOrNot']).size().reset_index(name = 'Count')
plt.figure(figsize = (10,6))
#sns.barplot(x = 'Education', y = 'Count', hue = 'LeaveOrNot', data = edu_leave)
bars = plt.bar(x= 'Education', data= edu_leave, height= 'Count', bottom= 0, width= 0.3, align= 'edge')
bars[0].set_color('green')
bars[1].set_color('blue')
bars[2].set_color('green')
bars[3].set_color('blue')
bars[4].set_color('green')
bars[5].set_color('blue')
plt.title("Education ~ Leave or Not")
plt.show()

# %%
edu_leave.plot.scatter(y="Education", x = 'Count')
# Out:
# <Axes: xlabel='Count', ylabel='Education'>
