# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Employee.csv")

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.sort_values(by='Age')
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4472  Bachelors         2017  New Delhi            2   22    Male          No
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 19    Bachelors         2016  New Delhi            2   22  Female          No
# 25    Bachelors         2013  Bangalore            3   22  Female         Yes
# 4400  Bachelors         2017       Pune            2   22  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 3321  Bachelors         2014  Bangalore            3   41    Male          No
# 3004  Bachelors         2016  Bangalore            3   41    Male          No
# 3821        PHD         2013  Bangalore            3   41    Male          No
# 3813  Bachelors         2014  New Delhi            3   41    Male          No
# 3890  Bachelors         2017  Bangalore            3   41    Male          No
#
# ...

# %%
main = df.groupby(by='Gender')

# %%
main.plot.hexbin(x='ExperienceInCurrentDomain',y='JoiningYear', title= "Density by Experience and Joining year")
# Out:
# Gender
# Female    Axes(0.125,0.11;0.62x0.77)
# Male      Axes(0.125,0.11;0.62x0.77)
# dtype: object

# %%
df['Age'].plot.kde()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df['Age'].plot.kde()
#
# File ~/Documents/Interpreter/lib/python3.9/site-packages/pandas/plotting/_core.py:1525, in PlotAccessor.kde(self, bw_method, ind, **kwargs)
#    1414 def kde(
#    1415     self,
#    1416     bw_method: Literal["scott", "silverman"] | float | Callable | None = None,
#    1417     ind: np.ndarray | int | None = None,
#    1418     **kwargs,
#    1419 ) -> PlotAccessor:
#    1420     """
#    1421     Generate Kernel Density Estimate plot using Gaussian kernels.
#    1422
#    (...)
#    1523         >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1524     """
# -> 1525     return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#
# File ~/Documents/Interpreter/lib/python3.9/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
# ...

# %%
df['PaymentTier'].plot.kde()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df['PaymentTier'].plot.kde()
#
# File ~/Documents/Interpreter/lib/python3.9/site-packages/pandas/plotting/_core.py:1525, in PlotAccessor.kde(self, bw_method, ind, **kwargs)
#    1414 def kde(
#    1415     self,
#    1416     bw_method: Literal["scott", "silverman"] | float | Callable | None = None,
#    1417     ind: np.ndarray | int | None = None,
#    1418     **kwargs,
#    1419 ) -> PlotAccessor:
#    1420     """
#    1421     Generate Kernel Density Estimate plot using Gaussian kernels.
#    1422
#    (...)
#    1523         >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1524     """
# -> 1525     return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#
# ...

# %%
education = df.Education
df.plot.line('ExperienceInCurrentDomain')
# Out:
# <Axes: xlabel='ExperienceInCurrentDomain'>
